# %% [markdown]
# #### Import und Data Preparation der Kriminalstatistik

# %%
import pandas as pd
import numpy as np

# %%
url = "https://raw.githubusercontent.com/andreashrb/Python_for_DS_Project/main/data/Kriminalstatistik_Straftaten_2020.csv"

df_criminal = pd.read_csv(url,encoding="latin-1",skiprows=1,delimiter=";",usecols=range(18),decimal=',')
df_criminal.rename(columns={'Gemeindeschluessel':'Kreis_ID',
                           'Straftat':'Art_Straftat'},inplace=True)
df_criminal.drop(['Kreisart','Schluessel'],axis=1, inplace=True)


df_criminal.head()
# Out:
#            Art_Straftat  Kreis_ID Stadt-/Landkreis  Anzahl erfasste Faelle  \
# 0  Straftaten insgesamt      1001        Flensburg                   8.380
# 1  Straftaten insgesamt      1002             Kiel                  21.384
# 2  Straftaten insgesamt      1003           Lübeck                  20.942
# 3  Straftaten insgesamt      1004       Neumünster                   9.453
# 4  Straftaten insgesamt      1051     Dithmarschen                   6.597
#
#    Haeufigkeitszahl  erfasste Faelle, davon Versuche - Anzahl  \
# 0             9.294                                   598.000
# 1             8.665                                     1.413
# 2             9.672                                     1.513
# 3            11.787                                   672.000
# 4             4.953                                   457.000
#
#   erfasste Faelle, davon Versuche - Anteil in %  mit Schusswaffe gedroht  \
# 0                                           7.1                       11
# 1                                           6.6                       23
# 2                                           7.2                       26
# 3                                           7.1                        7
# 4                                           6.9                       13
#
#    mit Schusswaffe geschossen  Auffklaerung - Anzahl Faelle Aufklaerungsquote  \
# 0                           5                         5.293              63.2
# 1                           5                        11.241              52.6
# 2                          13                        11.959              57.1
# 3                           4                         5.836              61.7
# 4                          12                         3.944              59.8
#
#    Tatverdaechtige insgesamt  Tatverdaechtige - maennlich  \
# 0                      3.618                        2.786
# 1                      7.278                        5.616
# 2                      7.603                        5.762
# 3                      4.170                        3.097
# 4                      2.989                        2.231
#
#    Tatverdaechtige - weiblich  Nichtdeutsche Tatverdaechtige - Anzahl  \
# 0                     832.000                                   1.233
# 1                       1.662                                   2.072
# 2                       1.841                                   1.841
# 3                       1.073                                   1.955
# 4                     758.000                                 535.000
#
#   Nichtdeutsche Tatverdaechtige - Anteil in % an der Gesamtzahl
# 0                                               34.1
# 1                                               28.5
# 2                                               24.2
# 3                                               46.9
# 4                                               17.9

# %%
# Import und join der straftat_cluster

url_cluster = "https://raw.githubusercontent.com/andreashrb/Python_for_DS_Project/main/data/straftat_cluster.csv"

df_cluster = pd.read_csv(url_cluster, encoding="utf-8",delimiter=";")
df_cluster.rename(columns={'Straftatcluster':'Straftat_Cluster'},inplace=True)

df_criminal=pd.merge(df_criminal, df_cluster, left_on='Art_Straftat',right_on='Art_Straftat')

# %%
df_criminal.head()
# Out:
#            Art_Straftat  Kreis_ID Stadt-/Landkreis  Anzahl erfasste Faelle  \
# 0  Straftaten insgesamt      1001        Flensburg                   8.380
# 1  Straftaten insgesamt      1002             Kiel                  21.384
# 2  Straftaten insgesamt      1003           Lübeck                  20.942
# 3  Straftaten insgesamt      1004       Neumünster                   9.453
# 4  Straftaten insgesamt      1051     Dithmarschen                   6.597
#
#    Haeufigkeitszahl  erfasste Faelle, davon Versuche - Anzahl  \
# 0             9.294                                   598.000
# 1             8.665                                     1.413
# 2             9.672                                     1.513
# 3            11.787                                   672.000
# 4             4.953                                   457.000
#
#   erfasste Faelle, davon Versuche - Anteil in %  mit Schusswaffe gedroht  \
# 0                                           7.1                       11
# 1                                           6.6                       23
# 2                                           7.2                       26
# 3                                           7.1                        7
# 4                                           6.9                       13
#
#    mit Schusswaffe geschossen  Auffklaerung - Anzahl Faelle Aufklaerungsquote  \
# 0                           5                         5.293              63.2
# 1                           5                        11.241              52.6
# 2                          13                        11.959              57.1
# 3                           4                         5.836              61.7
# 4                          12                         3.944              59.8
#
#    Tatverdaechtige insgesamt  Tatverdaechtige - maennlich  \
# 0                      3.618                        2.786
# 1                      7.278                        5.616
# 2                      7.603                        5.762
# 3                      4.170                        3.097
# 4                      2.989                        2.231
#
#    Tatverdaechtige - weiblich  Nichtdeutsche Tatverdaechtige - Anzahl  \
# 0                     832.000                                   1.233
# 1                       1.662                                   2.072
# 2                       1.841                                   1.841
# 3                       1.073                                   1.955
# 4                     758.000                                 535.000
#
#   Nichtdeutsche Tatverdaechtige - Anteil in % an der Gesamtzahl  \
# 0                                               34.1
# 1                                               28.5
# 2                                               24.2
# 3                                               46.9
# 4                                               17.9
#
#        Straftat_Cluster
# 0  Straftaten insgesamt
# 1  Straftaten insgesamt
# 2  Straftaten insgesamt
# 3  Straftaten insgesamt
# 4  Straftaten insgesamt

# %%
# Löschen der drei relativen Spalten, um Group by auf Summe durchführen zu können.

df_criminal.drop(['erfasste Faelle, davon Versuche - Anteil in %','Aufklaerungsquote','Nichtdeutsche Tatverdaechtige - Anteil in % an der Gesamtzahl'],axis=1, inplace=True)

# %%
df_criminal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16842 entries, 0 to 16841
# Data columns (total 14 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Art_Straftat                              16842 non-null  object
#  1   Kreis_ID                                  16842 non-null  int64
#  2   Stadt-/Landkreis                          16842 non-null  object
#  3   Anzahl erfasste Faelle                    16842 non-null  float64
#  4   Haeufigkeitszahl                          16842 non-null  float64
#  5   erfasste Faelle, davon Versuche - Anzahl  16842 non-null  float64
#  6   mit Schusswaffe gedroht                   16842 non-null  int64
#  7   mit Schusswaffe geschossen                16842 non-null  int64
#  8   Auffklaerung - Anzahl Faelle              16842 non-null  float64
#  9   Tatverdaechtige insgesamt                 16842 non-null  float64
#  10  Tatverdaechtige - maennlich               16842 non-null  float64
#  11  Tatverdaechtige - weiblich                16842 non-null  float64
#  12  Nichtdeutsche Tatverdaechtige - Anzahl    16842 non-null  float64
#  13  Straftat_Cluster                          16842 non-null  object
# dtypes: float64(8), int64(3), object(3)
# memory usage: 1.9+ MB

# %%
# Group by auf Spalten Kreis_ID, Straftatcluster, Stadt-/Landkreis

df_criminal_grouped = df_criminal.groupby(['Kreis_ID','Straftat_Cluster','Stadt-/Landkreis']).sum()

df_criminal_grouped.head()
# Out:
#                                                                               Anzahl erfasste Faelle  \
# Kreis_ID Straftat_Cluster                                   Stadt-/Landkreis
# 1001     Beförderungserschleichung                          Flensburg                           57.0
#          Begünstigung, Strafvereitelung, Hehlerei, Geldw... Flensburg                           25.0
#          Betrug                                             Flensburg                          797.0
#          Brandstiftung                                      Flensburg                           28.0
#          Cyberkriminalität                                  Flensburg                          172.0
#
#                                                                               Haeufigkeitszahl  \
# Kreis_ID Straftat_Cluster                                   Stadt-/Landkreis
# 1001     Beförderungserschleichung                          Flensburg                     63.0
#          Begünstigung, Strafvereitelung, Hehlerei, Geldw... Flensburg                     28.0
#          Betrug                                             Flensburg                    884.0
#          Brandstiftung                                      Flensburg                     31.0
#          Cyberkriminalität                                  Flensburg                    191.0
#
#                                                                               erfasste Faelle, davon Versuche - Anzahl  \
# Kreis_ID Straftat_Cluster                                   Stadt-/Landkreis
# 1001     Beförderungserschleichung                          Flensburg                                              0.0
#          Begünstigung, Strafvereitelung, Hehlerei, Geldw... Flensburg                                              0.0
#          Betrug                                             Flensburg                                             74.0
#          Brandstiftung                                      Flensburg                                              4.0
#          Cyberkriminalität                                  Flensburg                                             36.0
#
#                                                                               mit Schusswaffe gedroht  \
# Kreis_ID Straftat_Cluster                                   Stadt-/Landkreis
# 1001     Beförderungserschleichung                          Flensburg                               0
#          Begünstigung, Strafvereitelung, Hehlerei, Geldw... Flensburg                               0
#          Betrug                                             Flensburg                               0
#          Brandstiftung                                      Flensburg                               0
#          Cyberkriminalität                                  Flensburg                               0
#
#                                                                               mit Schusswaffe geschossen  \
# Kreis_ID Straftat_Cluster                                   Stadt-/Landkreis
# 1001     Beförderungserschleichung                          Flensburg                                  0
#          Begünstigung, Strafvereitelung, Hehlerei, Geldw... Flensburg                                  0
#          Betrug                                             Flensburg                                  0
#          Brandstiftung                                      Flensburg                                  0
#          Cyberkriminalität                                  Flensburg                                  0
#
#                                                                               Auffklaerung - Anzahl Faelle  \
# Kreis_ID Straftat_Cluster                                   Stadt-/Landkreis
# 1001     Beförderungserschleichung                          Flensburg                                 56.0
#          Begünstigung, Strafvereitelung, Hehlerei, Geldw... Flensburg                                 24.0
#          Betrug                                             Flensburg                                585.0
#          Brandstiftung                                      Flensburg                                 12.0
#          Cyberkriminalität                                  Flensburg                                 84.0
#
#                                                                               Tatverdaechtige insgesamt  \
# Kreis_ID Straftat_Cluster                                   Stadt-/Landkreis
# 1001     Beförderungserschleichung                          Flensburg                              56.0
#          Begünstigung, Strafvereitelung, Hehlerei, Geldw... Flensburg                              27.0
#          Betrug                                             Flensburg                             442.0
#          Brandstiftung                                      Flensburg                              12.0
#          Cyberkriminalität                                  Flensburg                              60.0
#
#                                                                               Tatverdaechtige - maennlich  \
# Kreis_ID Straftat_Cluster                                   Stadt-/Landkreis
# 1001     Beförderungserschleichung                          Flensburg                                37.0
#          Begünstigung, Strafvereitelung, Hehlerei, Geldw... Flensburg                                20.0
#          Betrug                                             Flensburg                               294.0
#          Brandstiftung                                      Flensburg                                 8.0
#          Cyberkriminalität                                  Flensburg                                43.0
#
#                                                                               Tatverdaechtige - weiblich  \
# Kreis_ID Straftat_Cluster                                   Stadt-/Landkreis
# 1001     Beförderungserschleichung                          Flensburg                               19.0
#          Begünstigung, Strafvereitelung, Hehlerei, Geldw... Flensburg                                7.0
#          Betrug                                             Flensburg                              148.0
#          Brandstiftung                                      Flensburg                                4.0
#          Cyberkriminalität                                  Flensburg                               17.0
#
#                                                                               Nichtdeutsche Tatverdaechtige - Anzahl
# Kreis_ID Straftat_Cluster                                   Stadt-/Landkreis
# 1001     Beförderungserschleichung                          Flensburg                                           34.0
#          Begünstigung, Strafvereitelung, Hehlerei, Geldw... Flensburg                                            9.0
#          Betrug                                             Flensburg                                          107.0
#          Brandstiftung                                      Flensburg                                            2.0
#          Cyberkriminalität                                  Flensburg                                           17.0

# %%
df_criminal_grouped = df_criminal_grouped.reset_index(drop=False)
df_criminal_grouped.head()
# Out:
#    Kreis_ID                                   Straftat_Cluster  \
# 0      1001                          Beförderungserschleichung
# 1      1001  Begünstigung, Strafvereitelung, Hehlerei, Geld...
# 2      1001                                             Betrug
# 3      1001                                      Brandstiftung
# 4      1001                                  Cyberkriminalität
#
#   Stadt-/Landkreis  Anzahl erfasste Faelle  Haeufigkeitszahl  \
# 0        Flensburg                    57.0              63.0
# 1        Flensburg                    25.0              28.0
# 2        Flensburg                   797.0             884.0
# 3        Flensburg                    28.0              31.0
# 4        Flensburg                   172.0             191.0
#
#    erfasste Faelle, davon Versuche - Anzahl  mit Schusswaffe gedroht  \
# 0                                       0.0                        0
# 1                                       0.0                        0
# 2                                      74.0                        0
# 3                                       4.0                        0
# 4                                      36.0                        0
#
#    mit Schusswaffe geschossen  Auffklaerung - Anzahl Faelle  \
# 0                           0                          56.0
# 1                           0                          24.0
# 2                           0                         585.0
# 3                           0                          12.0
# 4                           0                          84.0
#
#    Tatverdaechtige insgesamt  Tatverdaechtige - maennlich  \
# 0                       56.0                         37.0
# 1                       27.0                         20.0
# 2                      442.0                        294.0
# 3                       12.0                          8.0
# 4                       60.0                         43.0
#
#    Tatverdaechtige - weiblich  Nichtdeutsche Tatverdaechtige - Anzahl
# 0                        19.0                                    34.0
# 1                         7.0                                     9.0
# 2                       148.0                                   107.0
# 3                         4.0                                     2.0
# 4                        17.0                                    17.0

# %%
# Neuberechnung der relativen Spalten

df_criminal_grouped['erfasste Faelle, davon Versuche - Anteil in %'] = np.where(df_criminal_grouped["erfasste Faelle, davon Versuche - Anzahl"] == 0, 0.00, (df_criminal_grouped["erfasste Faelle, davon Versuche - Anzahl"] / df_criminal_grouped["Anzahl erfasste Faelle"])*100)
# df_criminal_grouped['erfasste Faelle, davon Versuche - Anteil in %']=(df_criminal_grouped["erfasste Faelle, davon Versuche - Anzahl"] / df_criminal_grouped["Anzahl erfasste Faelle"])*100

df_criminal_grouped['Aufklaerungsquote in %'] = np.where(df_criminal_grouped['Auffklaerung - Anzahl Faelle'] == 0, 0.00, (df_criminal_grouped['Auffklaerung - Anzahl Faelle'] / df_criminal_grouped["Anzahl erfasste Faelle"])*100)
# df_criminal_grouped['Aufklaerungsquote in %']=(df_criminal_grouped['Auffklaerung - Anzahl Faelle'] / df_criminal_grouped["Anzahl erfasste Faelle"])*100

df_criminal_grouped['Nichtdeutsche Tatverdaechtige - Anteil in % an der Gesamtzahl'] = np.where(df_criminal_grouped['Nichtdeutsche Tatverdaechtige - Anzahl'] == 0, 0.00, (df_criminal_grouped['Nichtdeutsche Tatverdaechtige - Anzahl'] / df_criminal_grouped['Tatverdaechtige insgesamt'])*100)
# df_criminal_grouped['Nichtdeutsche Tatverdaechtige - Anteil in % an der Gesamtzahl']=(df_criminal_grouped['Nichtdeutsche Tatverdaechtige - Anzahl'] / df_criminal_grouped['Tatverdaechtige insgesamt'])*100

# %%
df_criminal_grouped.head()
# Out:
#    Kreis_ID                                   Straftat_Cluster  \
# 0      1001                          Beförderungserschleichung
# 1      1001  Begünstigung, Strafvereitelung, Hehlerei, Geld...
# 2      1001                                             Betrug
# 3      1001                                      Brandstiftung
# 4      1001                                  Cyberkriminalität
#
#   Stadt-/Landkreis  Anzahl erfasste Faelle  Haeufigkeitszahl  \
# 0        Flensburg                    57.0              63.0
# 1        Flensburg                    25.0              28.0
# 2        Flensburg                   797.0             884.0
# 3        Flensburg                    28.0              31.0
# 4        Flensburg                   172.0             191.0
#
#    erfasste Faelle, davon Versuche - Anzahl  mit Schusswaffe gedroht  \
# 0                                       0.0                        0
# 1                                       0.0                        0
# 2                                      74.0                        0
# 3                                       4.0                        0
# 4                                      36.0                        0
#
#    mit Schusswaffe geschossen  Auffklaerung - Anzahl Faelle  \
# 0                           0                          56.0
# 1                           0                          24.0
# 2                           0                         585.0
# 3                           0                          12.0
# 4                           0                          84.0
#
#    Tatverdaechtige insgesamt  Tatverdaechtige - maennlich  \
# 0                       56.0                         37.0
# 1                       27.0                         20.0
# 2                      442.0                        294.0
# 3                       12.0                          8.0
# 4                       60.0                         43.0
#
#    Tatverdaechtige - weiblich  Nichtdeutsche Tatverdaechtige - Anzahl  \
# 0                        19.0                                    34.0
# 1                         7.0                                     9.0
# 2                       148.0                                   107.0
# 3                         4.0                                     2.0
# 4                        17.0                                    17.0
#
#    erfasste Faelle, davon Versuche - Anteil in %  Aufklaerungsquote in %  \
# 0                                       0.000000               98.245614
# 1                                       0.000000               96.000000
# 2                                       9.284818               73.400251
# 3                                      14.285714               42.857143
# 4                                      20.930233               48.837209
#
#    Nichtdeutsche Tatverdaechtige - Anteil in % an der Gesamtzahl
# 0                                          60.714286
# 1                                          33.333333
# 2                                          24.208145
# 3                                          16.666667
# 4                                          28.333333

# %%
df_criminal_grouped.isnull().sum().sort_values(ascending=False).head(20)
# Out:
# Kreis_ID                                                         0
# Straftat_Cluster                                                 0
# Stadt-/Landkreis                                                 0
# Anzahl erfasste Faelle                                           0
# Haeufigkeitszahl                                                 0
# erfasste Faelle, davon Versuche - Anzahl                         0
# mit Schusswaffe gedroht                                          0
# mit Schusswaffe geschossen                                       0
# Auffklaerung - Anzahl Faelle                                     0
# Tatverdaechtige insgesamt                                        0
# Tatverdaechtige - maennlich                                      0
# Tatverdaechtige - weiblich                                       0
# Nichtdeutsche Tatverdaechtige - Anzahl                           0
# erfasste Faelle, davon Versuche - Anteil in %                    0
# Aufklaerungsquote in %                                           0
# Nichtdeutsche Tatverdaechtige - Anteil in % an der Gesamtzahl    0
# dtype: int64
